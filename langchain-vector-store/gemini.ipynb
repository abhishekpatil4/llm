# %%
# !pip3 install -U langchain-google-genai
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Collecting langchain-google-genai
#   Downloading langchain_google_genai-1.0.7-py3-none-any.whl.metadata (3.8 kB)
# Collecting google-generativeai<0.8.0,>=0.7.0 (from langchain-google-genai)
#   Downloading google_generativeai-0.7.2-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: langchain-core<0.3,>=0.2.9 in /usr/local/lib/python3.9/site-packages (from langchain-google-genai) (0.2.21)
# Collecting google-ai-generativelanguage==0.6.6 (from google-generativeai<0.8.0,>=0.7.0->langchain-google-genai)
#   Downloading google_ai_generativelanguage-0.6.6-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: google-api-core in /usr/local/lib/python3.9/site-packages (from google-generativeai<0.8.0,>=0.7.0->langchain-google-genai) (2.19.1)
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.9/site-packages (from google-generativeai<0.8.0,>=0.7.0->langchain-google-genai) (2.52.0)
# Requirement already satisfied: google-auth>=2.15.0 in /usr/local/lib/python3.9/site-packages (from google-generativeai<0.8.0,>=0.7.0->langchain-google-genai) (2.32.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.9/site-packages (from google-generativeai<0.8.0,>=0.7.0->langchain-google-genai) (4.25.3)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.9/site-packages (from google-generativeai<0.8.0,>=0.7.0->langchain-google-genai) (2.8.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/site-packages (from google-generativeai<0.8.0,>=0.7.0->langchain-google-genai) (4.65.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/site-packages (from google-generativeai<0.8.0,>=0.7.0->langchain-google-genai) (4.12.2)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.9/site-packages (from google-ai-generativelanguage==0.6.6->google-generativeai<0.8.0,>=0.7.0->langchain-google-genai) (1.24.0)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.9/site-packages (from langchain-core<0.3,>=0.2.9->langchain-google-genai) (6.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.9/site-packages (from langchain-core<0.3,>=0.2.9->langchain-google-genai) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.75 in /usr/local/lib/python3.9/site-packages (from langchain-core<0.3,>=0.2.9->langchain-google-genai) (0.1.90)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.9/site-packages (from langchain-core<0.3,>=0.2.9->langchain-google-genai) (24.1)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /usr/local/lib/python3.9/site-packages (from langchain-core<0.3,>=0.2.9->langchain-google-genai) (8.5.0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.9/site-packages (from google-api-core->google-generativeai<0.8.0,>=0.7.0->langchain-google-genai) (1.56.3)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in /usr/local/lib/python3.9/site-packages (from google-api-core->google-generativeai<0.8.0,>=0.7.0->langchain-google-genai) (2.32.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.9/site-packages (from google-auth>=2.15.0->google-generativeai<0.8.0,>=0.7.0->langchain-google-genai) (5.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.9/site-packages (from google-auth>=2.15.0->google-generativeai<0.8.0,>=0.7.0->langchain-google-genai) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.9/site-packages (from google-auth>=2.15.0->google-generativeai<0.8.0,>=0.7.0->langchain-google-genai) (4.8)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.9/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3,>=0.2.9->langchain-google-genai) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.9/site-packages (from langsmith<0.2.0,>=0.1.75->langchain-core<0.3,>=0.2.9->langchain-google-genai) (3.10.6)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.9/site-packages (from pydantic->google-generativeai<0.8.0,>=0.7.0->langchain-google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /usr/local/lib/python3.9/site-packages (from pydantic->google-generativeai<0.8.0,>=0.7.0->langchain-google-genai) (2.20.1)
# Requirement already satisfied: httplib2<1dev,>=0.15.0 in /usr/local/lib/python3.9/site-packages (from google-api-python-client->google-generativeai<0.8.0,>=0.7.0->langchain-google-genai) (0.20.4)
# Requirement already satisfied: google-auth-httplib2>=0.1.0 in /usr/local/lib/python3.9/site-packages (from google-api-python-client->google-generativeai<0.8.0,>=0.7.0->langchain-google-genai) (0.1.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.9/site-packages (from google-api-python-client->google-generativeai<0.8.0,>=0.7.0->langchain-google-genai) (4.1.1)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /usr/local/lib/python3.9/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.6->google-generativeai<0.8.0,>=0.7.0->langchain-google-genai) (1.65.1)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /usr/local/lib/python3.9/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.6->google-generativeai<0.8.0,>=0.7.0->langchain-google-genai) (1.47.0)
# Requirement already satisfied: six in /Users/abhishekpatil/Library/Python/3.9/lib/python/site-packages (from google-auth-httplib2>=0.1.0->google-api-python-client->google-generativeai<0.8.0,>=0.7.0->langchain-google-genai) (1.16.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /Users/abhishekpatil/Library/Python/3.9/lib/python/site-packages (from httplib2<1dev,>=0.15.0->google-api-python-client->google-generativeai<0.8.0,>=0.7.0->langchain-google-genai) (3.0.9)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai<0.8.0,>=0.7.0->langchain-google-genai) (0.4.8)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.9/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai<0.8.0,>=0.7.0->langchain-google-genai) (2.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai<0.8.0,>=0.7.0->langchain-google-genai) (3.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.9/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai<0.8.0,>=0.7.0->langchain-google-genai) (1.26.19)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai<0.8.0,>=0.7.0->langchain-google-genai) (2022.6.15)
# Downloading langchain_google_genai-1.0.7-py3-none-any.whl (36 kB)
# Downloading google_generativeai-0.7.2-py3-none-any.whl (164 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.2/164.2 kB 4.2 MB/s eta 0:00:0000:01
# Downloading google_ai_generativelanguage-0.6.6-py3-none-any.whl (718 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 718.3/718.3 kB 9.3 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: google-ai-generativelanguage, google-generativeai, langchain-google-genai
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Successfully installed google-ai-generativelanguage-0.6.6 google-generativeai-0.7.2 langchain-google-genai-1.0.7
#
# [notice] A new release of pip is available: 23.3.1 -> 24.1.2
# [notice] To update, run: python3.9 -m pip install --upgrade pip

# %%
import os
import getpass

# %%
os.environ["OPENAI_API_KEY"] = getpass.getpass()
# Out:
#  ········

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(model="gemini-pro")
res = llm.invoke("Say hi")
print(res)
# Out:
# I0000 00:00:1721327368.189153 6240686 check_gcp_environment_no_op.cc:29] ALTS: Platforms other than Linux and Windows are not supported
# I0000 00:00:1721327368.189866 6240686 check_gcp_environment_no_op.cc:29] ALTS: Platforms other than Linux and Windows are not supported
# content='Hi there! How can I help you today?' response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': [{'category': 'HARM_CATEGORY_SEXUALLY_EXPLICIT', 'probability': 'NEGLIGIBLE', 'blocked': False}, {'category': 'HARM_CATEGORY_HATE_SPEECH', 'probability': 'NEGLIGIBLE', 'blocked': False}, {'category': 'HARM_CATEGORY_HARASSMENT', 'probability': 'NEGLIGIBLE', 'blocked': False}, {'category': 'HARM_CATEGORY_DANGEROUS_CONTENT', 'probability': 'NEGLIGIBLE', 'blocked': False}]} id='run-78683d9a-437f-4951-b1ce-3e0c10fff542-0' usage_metadata={'input_tokens': 3, 'output_tokens': 10, 'total_tokens': 13}

# %%
from langchain_core.documents import Document

documents = [
    Document(
        page_content="Dogs are great companions, known for their loyalty and friendliness.",
        metadata={"source": "mammal-pets-doc"},
    ),
    Document(
        page_content="Cats are independent pets that often enjoy their own space.",
        metadata={"source": "mammal-pets-doc"},
    ),
    Document(
        page_content="Goldfish are popular pets for beginners, requiring relatively simple care.",
        metadata={"source": "fish-pets-doc"},
    ),
    Document(
        page_content="Parrots are intelligent birds capable of mimicking human speech.",
        metadata={"source": "bird-pets-doc"},
    ),
    Document(
        page_content="Rabbits are social animals that need plenty of space to hop around.",
        metadata={"source": "mammal-pets-doc"},
    ),
]

# %%
pip install langchain langchain-chroma langchain-openai
# Out:
# I0000 00:00:1721327444.534438 6240686 work_stealing_thread_pool.cc:320] WorkStealingThreadPoolImpl::PrepareFork
# I0000 00:00:1721327444.534628 6240686 fork_posix.cc:77] Other threads are currently calling into gRPC, skipping fork() handlers
# Collecting langchain
#   Downloading langchain-0.2.9-py3-none-any.whl (987 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 987.7/987.7 KB 5.6 MB/s eta 0:00:00a 0:00:01
# Collecting langchain-chroma
#   Downloading langchain_chroma-0.1.2-py3-none-any.whl (9.3 kB)
# Collecting langchain-openai
#   Downloading langchain_openai-0.1.17-py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.7/46.7 KB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from langchain) (0.1.90)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.20 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from langchain) (0.2.21)
# Requirement already satisfied: PyYAML>=5.3 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from langchain) (6.0)
# Requirement already satisfied: pydantic<3,>=1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from langchain) (1.10.2)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from langchain) (4.0.2)
# Requirement already satisfied: requests<3,>=2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from langchain) (2.32.3)
# Requirement already satisfied: numpy<2,>=1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from langchain) (1.24.3)
# Collecting langchain-text-splitters<0.3.0,>=0.2.0
#   Downloading langchain_text_splitters-0.2.2-py3-none-any.whl (25 kB)
# Collecting aiohttp<4.0.0,>=3.8.3
#   Downloading aiohttp-3.9.5-cp310-cp310-macosx_10_9_x86_64.whl (400 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.7/400.7 KB 6.7 MB/s eta 0:00:0000:01
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from langchain) (8.5.0)
# Collecting SQLAlchemy<3,>=1.4
#   Downloading SQLAlchemy-2.0.31-cp310-cp310-macosx_10_9_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 2.7 MB/s eta 0:00:0000:0100:01
# Collecting chromadb<0.6.0,>=0.4.0
#   Downloading chromadb-0.5.4-py3-none-any.whl (581 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 581.4/581.4 KB 4.9 MB/s eta 0:00:0000:0100:01
# Collecting fastapi<1,>=0.95.2
#   Downloading fastapi-0.111.1-py3-none-any.whl (92 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.2/92.2 KB 3.9 MB/s eta 0:00:00
# Collecting openai<2.0.0,>=1.32.0
#   Downloading openai-1.35.15-py3-none-any.whl (328 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 328.6/328.6 KB 1.7 MB/s eta 0:00:00a 0:00:01
# Collecting tiktoken<1,>=0.7
#   Downloading tiktoken-0.7.0-cp310-cp310-macosx_10_9_x86_64.whl (961 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 961.5/961.5 KB 3.7 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: attrs>=17.3.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.2.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.8.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.2)
# Collecting bcrypt>=4.0.1
#   Downloading bcrypt-4.1.3-cp39-abi3-macosx_10_12_universal2.whl (506 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 506.5/506.5 KB 3.9 MB/s eta 0:00:0000:0100:01
# Collecting typing-extensions>=4.5.0
#   Downloading typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Collecting opentelemetry-sdk>=1.2.0
#   Downloading opentelemetry_sdk-1.25.0-py3-none-any.whl (107 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.0/107.0 KB 2.3 MB/s eta 0:00:00a 0:00:01
# Collecting posthog>=2.4.0
#   Downloading posthog-3.5.0-py2.py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 KB 1.6 MB/s eta 0:00:00
# Collecting pypika>=0.48.9
#   Downloading PyPika-0.48.9.tar.gz (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 KB 1.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: uvicorn[standard]>=0.18.3 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma) (0.18.3)
# Requirement already satisfied: orjson>=3.9.12 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma) (3.10.6)
# Collecting opentelemetry-instrumentation-fastapi>=0.41b0
#   Downloading opentelemetry_instrumentation_fastapi-0.46b0-py3-none-any.whl (11 kB)
# Requirement already satisfied: tqdm>=4.65.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma) (4.65.0)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.25.0-py3-none-any.whl (18 kB)
# Collecting typer>=0.9.0
#   Downloading typer-0.12.3-py3-none-any.whl (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.2/47.2 KB 2.3 MB/s eta 0:00:00
# Collecting mmh3>=4.0.1
#   Downloading mmh3-4.1.0-cp310-cp310-macosx_10_9_x86_64.whl (29 kB)
# Collecting build>=1.0.3
#   Downloading build-1.2.1-py3-none-any.whl (21 kB)
# Collecting chroma-hnswlib==0.7.5
#   Downloading chroma_hnswlib-0.7.5-cp310-cp310-macosx_10_9_x86_64.whl (195 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.8/195.8 KB 3.3 MB/s eta 0:00:00a 0:00:01
# Collecting tokenizers>=0.13.2
#   Downloading tokenizers-0.19.1-cp310-cp310-macosx_10_12_x86_64.whl (2.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 1.3 MB/s eta 0:00:0000:0100:010m
# Collecting importlib-resources
#   Downloading importlib_resources-6.4.0-py3-none-any.whl (38 kB)
# Collecting opentelemetry-api>=1.2.0
#   Downloading opentelemetry_api-1.25.0-py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.9/59.9 KB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: onnxruntime>=1.14.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma) (1.15.1)
# Requirement already satisfied: httpx>=0.27.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma) (0.27.0)
# Requirement already satisfied: grpcio>=1.58.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma) (1.65.1)
# Collecting kubernetes>=28.1.0
#   Downloading kubernetes-30.1.0-py2.py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 1.3 MB/s eta 0:00:0000:0100:010m
# Requirement already satisfied: overrides>=7.3.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma) (7.7.0)
# Collecting email_validator>=2.0.0
#   Downloading email_validator-2.2.0-py3-none-any.whl (33 kB)
# Requirement already satisfied: jinja2>=2.11.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from fastapi<1,>=0.95.2->langchain-chroma) (3.1.2)
# Collecting starlette<0.38.0,>=0.37.2
#   Downloading starlette-0.37.2-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.9/71.9 KB 1.2 MB/s eta 0:00:00a 0:00:01
# Collecting fastapi-cli>=0.0.2
#   Downloading fastapi_cli-0.0.4-py3-none-any.whl (9.5 kB)
# Collecting python-multipart>=0.0.7
#   Downloading python_multipart-0.0.9-py3-none-any.whl (22 kB)
# Requirement already satisfied: packaging<25,>=23.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from langchain-core<0.3.0,>=0.2.20->langchain) (24.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from langchain-core<0.3.0,>=0.2.20->langchain) (1.33)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from openai<2.0.0,>=1.32.0->langchain-openai) (3.6.2)
# Requirement already satisfied: sniffio in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from openai<2.0.0,>=1.32.0->langchain-openai) (1.3.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from openai<2.0.0,>=1.32.0->langchain-openai) (1.9.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests<3,>=2->langchain) (2022.9.24)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests<3,>=2->langchain) (1.26.12)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests<3,>=2->langchain) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests<3,>=2->langchain) (3.4)
# Collecting greenlet!=0.4.17
#   Downloading greenlet-3.0.3-cp310-cp310-macosx_11_0_universal2.whl (270 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 270.1/270.1 KB 2.6 MB/s eta 0:00:00a 0:00:01
# Collecting regex>=2022.1.18
#   Downloading regex-2024.5.15-cp310-cp310-macosx_10_9_x86_64.whl (281 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 281.7/281.7 KB 185.6 kB/s eta 0:00:0000:0100:01
# Requirement already satisfied: tomli>=1.1.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from build>=1.0.3->chromadb<0.6.0,>=0.4.0->langchain-chroma) (2.0.1)
# Collecting pyproject_hooks
#   Downloading pyproject_hooks-1.1.0-py3-none-any.whl (9.2 kB)
# Requirement already satisfied: importlib-metadata>=4.6 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from build>=1.0.3->chromadb<0.6.0,>=0.4.0->langchain-chroma) (7.1.0)
# Collecting dnspython>=2.0.0
#   Downloading dnspython-2.6.1-py3-none-any.whl (307 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 KB 802.8 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: httpcore==1.* in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from httpx>=0.27.0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (0.14.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from jinja2>=2.11.2->fastapi<1,>=0.95.2->langchain-chroma) (2.1.1)
# Requirement already satisfied: jsonpointer>=1.9 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.20->langchain) (3.0.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (2.8.2)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (1.8.0)
# Requirement already satisfied: requests-oauthlib in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (1.3.1)
# Requirement already satisfied: google-auth>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (2.29.0)
# Collecting oauthlib>=3.2.2
#   Using cached oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Requirement already satisfied: six>=1.9.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (1.16.0)
# Requirement already satisfied: protobuf in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb<0.6.0,>=0.4.0->langchain-chroma) (4.23.4)
# Requirement already satisfied: coloredlogs in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb<0.6.0,>=0.4.0->langchain-chroma) (15.0.1)
# Requirement already satisfied: sympy in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb<0.6.0,>=0.4.0->langchain-chroma) (1.11.1)
# Requirement already satisfied: flatbuffers in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb<0.6.0,>=0.4.0->langchain-chroma) (24.3.25)
# Collecting deprecated>=1.2.6
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Collecting opentelemetry-proto==1.25.0
#   Downloading opentelemetry_proto-1.25.0-py3-none-any.whl (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.5/52.5 KB 1.1 MB/s eta 0:00:0000:01
# Collecting opentelemetry-exporter-otlp-proto-common==1.25.0
#   Downloading opentelemetry_exporter_otlp_proto_common-1.25.0-py3-none-any.whl (17 kB)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (1.63.2)
# Collecting opentelemetry-util-http==0.46b0
#   Downloading opentelemetry_util_http-0.46b0-py3-none-any.whl (6.9 kB)
# Collecting opentelemetry-instrumentation-asgi==0.46b0
#   Downloading opentelemetry_instrumentation_asgi-0.46b0-py3-none-any.whl (14 kB)
# Collecting opentelemetry-semantic-conventions==0.46b0
#   Downloading opentelemetry_semantic_conventions-0.46b0-py3-none-any.whl (130 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.5/130.5 KB 2.2 MB/s eta 0:00:00a 0:00:01
# Collecting opentelemetry-instrumentation==0.46b0
#   Downloading opentelemetry_instrumentation-0.46b0-py3-none-any.whl (29 kB)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from opentelemetry-instrumentation==0.46b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (1.14.1)
# Requirement already satisfied: setuptools>=16.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from opentelemetry-instrumentation==0.46b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (58.1.0)
# Requirement already satisfied: asgiref~=3.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from opentelemetry-instrumentation-asgi==0.46b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (3.5.2)
# Collecting monotonic>=1.5
#   Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Collecting backoff>=1.10.0
#   Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Collecting huggingface-hub<1.0,>=0.16.4
#   Downloading huggingface_hub-0.24.0-py3-none-any.whl (419 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 419.0/419.0 KB 2.3 MB/s eta 0:00:00a 0:00:01
# Collecting rich>=10.11.0
#   Downloading rich-13.7.1-py3-none-any.whl (240 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.7/240.7 KB 2.5 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: click>=8.0.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from typer>=0.9.0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (8.0.4)
# Collecting shellingham>=1.3.0
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Collecting httptools>=0.4.0
#   Downloading httptools-0.6.1-cp310-cp310-macosx_10_9_x86_64.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.6/77.6 KB 1.9 MB/s eta 0:00:00
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0
#   Downloading uvloop-0.19.0-cp310-cp310-macosx_10_9_x86_64.whl (793 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 793.9/793.9 KB 1.4 MB/s eta 0:00:00a 0:00:01
# Collecting watchfiles>=0.13
#   Downloading watchfiles-0.22.0-cp310-cp310-macosx_10_12_x86_64.whl (394 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 395.0/395.0 KB 2.9 MB/s eta 0:00:00a 0:00:01
# Collecting websockets>=10.0
#   Downloading websockets-12.0-cp310-cp310-macosx_10_9_x86_64.whl (121 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.3/121.3 KB 3.0 MB/s eta 0:00:00a 0:00:01
# Collecting python-dotenv>=0.13
#   Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (5.2.0)
# Collecting fsspec>=2023.5.0
#   Downloading fsspec-2024.6.1-py3-none-any.whl (177 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.6/177.6 KB 3.2 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: filelock in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb<0.6.0,>=0.4.0->langchain-chroma) (3.12.2)
# Requirement already satisfied: zipp>=0.5 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from importlib-metadata>=4.6->build>=1.0.3->chromadb<0.6.0,>=0.4.0->langchain-chroma) (3.18.1)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from rich>=10.11.0->typer>=0.9.0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (2.13.0)
# Collecting markdown-it-py>=2.2.0
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 KB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: humanfriendly>=9.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb<0.6.0,>=0.4.0->langchain-chroma) (10.0)
# Requirement already satisfied: mpmath>=0.19 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from sympy->onnxruntime>=1.14.1->chromadb<0.6.0,>=0.4.0->langchain-chroma) (1.2.1)
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (0.4.8)
# Building wheels for collected packages: pypika
#   Building wheel for pypika (pyproject.toml) ... done
#   Created wheel for pypika: filename=PyPika-0.48.9-py2.py3-none-any.whl size=53725 sha256=1099c0f1beacd0e7ca6f3e9447e47e53b156766deba0f9ef2b6348e0486e8552
#   Stored in directory: /Users/abhishekpatil/Library/Caches/pip/wheels/e1/26/51/d0bffb3d2fd82256676d7ad3003faea3bd6dddc9577af665f4
# Successfully built pypika
# Installing collected packages: pypika, monotonic, mmh3, websockets, uvloop, typing-extensions, shellingham, regex, python-multipart, python-dotenv, pyproject_hooks, opentelemetry-util-http, opentelemetry-proto, oauthlib, mdurl, importlib-resources, httptools, greenlet, fsspec, dnspython, deprecated, chroma-hnswlib, bcrypt, backoff, watchfiles, tiktoken, starlette, SQLAlchemy, posthog, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, markdown-it-py, huggingface-hub, email_validator, build, aiohttp, tokenizers, rich, opentelemetry-semantic-conventions, opentelemetry-instrumentation, openai, kubernetes, typer, opentelemetry-sdk, opentelemetry-instrumentation-asgi, opentelemetry-instrumentation-fastapi, opentelemetry-exporter-otlp-proto-grpc, langchain-text-splitters, langchain-openai, fastapi-cli, langchain, fastapi, chromadb, langchain-chroma
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.4.0
#     Uninstalling typing_extensions-4.4.0:
#       Successfully uninstalled typing_extensions-4.4.0
#   Attempting uninstall: python-multipart
#     Found existing installation: python-multipart 0.0.5
#     Uninstalling python-multipart-0.0.5:
#       Successfully uninstalled python-multipart-0.0.5
#   Attempting uninstall: oauthlib
#     Found existing installation: oauthlib 3.2.1
#     Uninstalling oauthlib-3.2.1:
#       Successfully uninstalled oauthlib-3.2.1
#   Attempting uninstall: starlette
#     Found existing installation: starlette 0.19.1
#     Uninstalling starlette-0.19.1:
#       Successfully uninstalled starlette-0.19.1
#   Attempting uninstall: aiohttp
#     Found existing installation: aiohttp 3.8.1
#     Uninstalling aiohttp-3.8.1:
#       Successfully uninstalled aiohttp-3.8.1
#   Attempting uninstall: fastapi
#     Found existing installation: fastapi 0.80.0
#     Uninstalling fastapi-0.80.0:
#       Successfully uninstalled fastapi-0.80.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.13.0 requires typing-extensions<4.6.0,>=3.6.6, but you have typing-extensions 4.12.2 which is incompatible.
# rembg 2.0.25 requires aiohttp==3.8.1, but you have aiohttp 3.9.5 which is incompatible.
# rembg 2.0.25 requires click==8.1.3, but you have click 8.0.4 which is incompatible.
# rembg 2.0.25 requires fastapi==0.80.0, but you have fastapi 0.111.1 which is incompatible.
# rembg 2.0.25 requires numpy==1.21.6, but you have numpy 1.24.3 which is incompatible.
# rembg 2.0.25 requires onnxruntime==1.12.1, but you have onnxruntime 1.15.1 which is incompatible.
# rembg 2.0.25 requires pillow==9.2.0, but you have pillow 10.0.0 which is incompatible.
# rembg 2.0.25 requires python-multipart==0.0.5, but you have python-multipart 0.0.9 which is incompatible.
# rembg 2.0.25 requires scipy==1.7.3, but you have scipy 1.13.0 which is incompatible.
# rembg 2.0.25 requires tqdm==4.64.0, but you have tqdm 4.65.0 which is incompatible.
# Successfully installed SQLAlchemy-2.0.31 aiohttp-3.9.5 backoff-2.2.1 bcrypt-4.1.3 build-1.2.1 chroma-hnswlib-0.7.5 chromadb-0.5.4 deprecated-1.2.14 dnspython-2.6.1 email_validator-2.2.0 fastapi-0.111.1 fastapi-cli-0.0.4 fsspec-2024.6.1 greenlet-3.0.3 httptools-0.6.1 huggingface-hub-0.24.0 importlib-resources-6.4.0 kubernetes-30.1.0 langchain-0.2.9 langchain-chroma-0.1.2 langchain-openai-0.1.17 langchain-text-splitters-0.2.2 markdown-it-py-3.0.0 mdurl-0.1.2 mmh3-4.1.0 monotonic-1.6 oauthlib-3.2.2 openai-1.35.15 opentelemetry-api-1.25.0 opentelemetry-exporter-otlp-proto-common-1.25.0 opentelemetry-exporter-otlp-proto-grpc-1.25.0 opentelemetry-instrumentation-0.46b0 opentelemetry-instrumentation-asgi-0.46b0 opentelemetry-instrumentation-fastapi-0.46b0 opentelemetry-proto-1.25.0 opentelemetry-sdk-1.25.0 opentelemetry-semantic-conventions-0.46b0 opentelemetry-util-http-0.46b0 posthog-3.5.0 pypika-0.48.9 pyproject_hooks-1.1.0 python-dotenv-1.0.1 python-multipart-0.0.9 regex-2024.5.15 rich-13.7.1 shellingham-1.5.4 starlette-0.37.2 tiktoken-0.7.0 tokenizers-0.19.1 typer-0.12.3 typing-extensions-4.12.2 uvloop-0.19.0 watchfiles-0.22.0 websockets-12.0
# WARNING: You are using pip version 22.0.4; however, version 24.1.2 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.10/bin/python3.10 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_chroma import Chroma
from langchain_openai import OpenAIEmbeddings

vectorstore = Chroma.from_documents(
    documents,
    embedding=OpenAIEmbeddings(),
)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[25], line 2
#       1 from langchain_chroma import Chroma
# ----> 2 from langchain_openai import OpenAIEmbeddings
#       4 vectorstore = Chroma.from_documents(
#       5     documents,
#       6     embedding=OpenAIEmbeddings(),
#       7 )
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/langchain_openai/__init__.py:1
# ----> 1 from langchain_openai.chat_models import AzureChatOpenAI, ChatOpenAI
#       2 from langchain_openai.embeddings import AzureOpenAIEmbeddings, OpenAIEmbeddings
#       3 from langchain_openai.llms import AzureOpenAI, OpenAI
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/langchain_openai/chat_models/__init__.py:1
# ----> 1 from langchain_openai.chat_models.azure import AzureChatOpenAI
#       2 from langchain_openai.chat_models.base import ChatOpenAI
#       4 __all__ = ["ChatOpenAI", "AzureChatOpenAI"]
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/langchain_openai/chat_models/azure.py:23
#       7 from operator import itemgetter
#       8 from typing import (
#       9     Any,
#      10     Callable,
#    (...)
#      20     overload,
#      21 )
# ---> 23 import openai
#      24 from langchain_core.language_models import LanguageModelInput
#      25 from langchain_core.language_models.chat_models import LangSmithParams
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/openai/__init__.py:8
#       5 import os as _os
#       6 from typing_extensions import override
# ----> 8 from . import types
#       9 from ._types import NOT_GIVEN, NoneType, NotGiven, Transport, ProxiesTypes
#      10 from ._utils import file_from_path
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/openai/types/__init__.py:5
#       1 # File generated from our OpenAPI spec by Stainless. See CONTRIBUTING.md for details.
#       3 from __future__ import annotations
# ----> 5 from .batch import Batch as Batch
#       6 from .image import Image as Image
#       7 from .model import Model as Model
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/openai/types/batch.py:7
#       4 from typing import List, Optional
#       5 from typing_extensions import Literal
# ----> 7 from .._models import BaseModel
#       8 from .batch_error import BatchError
#       9 from .batch_request_counts import BatchRequestCounts
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/openai/_models.py:36
#      23 from pydantic.fields import FieldInfo
#      25 from ._types import (
#      26     Body,
#      27     IncEx,
#    (...)
#      34     HttpxRequestFiles,
#      35 )
# ---> 36 from ._utils import (
#      37     PropertyInfo,
#      38     is_list,
#      39     is_given,
#      40     lru_cache,
#      41     is_mapping,
#      42     parse_date,
#      43     coerce_boolean,
#      44     parse_datetime,
#      45     strip_not_given,
#      46     extract_type_arg,
#      47     is_annotated_type,
#      48     strip_annotated_type,
#      49 )
#      50 from ._compat import (
#      51     PYDANTIC_V2,
#      52     ConfigDict,
#    (...)
#      61     field_get_default,
#      62 )
#      63 from ._constants import RAW_RESPONSE_HEADER
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/openai/_utils/__init__.py:44
#       3 from ._utils import (
#       4     flatten as flatten,
#       5     is_dict as is_dict,
#    (...)
#      32     maybe_coerce_integer as maybe_coerce_integer,
#      33 )
#      34 from ._typing import (
#      35     is_list_type as is_list_type,
#      36     is_union_type as is_union_type,
#    (...)
#      42     extract_type_var_from_base as extract_type_var_from_base,
#      43 )
# ---> 44 from ._streams import consume_sync_iterator as consume_sync_iterator, consume_async_iterator as consume_async_iterator
#      45 from ._transform import (
#      46     PropertyInfo as PropertyInfo,
#      47     transform as transform,
#    (...)
#      50     async_maybe_transform as async_maybe_transform,
#      51 )
#      52 from ._reflection import (
#      53     function_has_argument as function_has_argument,
#      54     assert_signatures_in_sync as assert_signatures_in_sync,
#      55 )
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/openai/_utils/_streams.py:2
#       1 from typing import Any
# ----> 2 from typing_extensions import Iterator, AsyncIterator
#       5 def consume_sync_iterator(iterator: Iterator[Any]) -> None:
#       6     for _ in iterator:
#
# ImportError: cannot import name 'Iterator' from 'typing_extensions' (/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/typing_extensions.py)
